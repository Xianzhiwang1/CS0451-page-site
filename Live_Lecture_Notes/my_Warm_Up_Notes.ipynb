# %%
import sklearn as sk
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
print("I did it!")
# Out:
# I did it!

# %%
z = np.linspace(0,5,101)
plt.plot(z, -np.log(1/(1+)))

X_ = np.append(X, np.ones())

def predict(X,w):
    return X@w

def logistic_loss(y_hat, y):
    return -y*np.log(sigmoid(y_hat)) - (1-y)*np.log(1-sigmoid(y_hat))

def sigmoid(y_hat):
    return 1/ ( 1 + np.exp(-y_hat))

def empirical_risk(W, y, w, loss):
    y_hat = predict(X,w)
    return loss(y_hat, y).mean()

# %%
result = minimize(lambda w: empirical_risk(X, y, w, logistic_loss))

# %% [markdown]
# Feb 22 2023

# %%
import numpy as np
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt


# make the data
p_features = 3
X_, y = make_blobs(n_samples = 200, n_features = p_features - 1, centers = [(-1, -1), (1, 1)])

fig = plt.scatter(X[:,0], X[:,1], c = y)
xlab = plt.xlabel("Feature 1")
ylab = plt.ylabel("Feature 2")



def f(w):
    return np.sin(w[0]*w[1])


def fgradient(w_0, w_1):
    return w_1 * np.cos(w_0 * w_1), w_0 * np.cos(w_0 * w_1)

max_epochs = 100
done = False

while (not done) and (i <= max_epochs): 
    w -= alpha * fgradient(w, X_, y)                   # gradient step
    new_loss = empirical_risk(X_, y, logistic_loss, w) # compute loss

    history.append(new_loss)
    # check if loss hasn't changed and terminate if so
    if np.isclose(new_loss, prev_loss):          
        done = True
    else:
        prev_loss = new_loss
    i += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 27
#      24 done = False
#      26 while (not done) and (i <= max_epochs):
# ---> 27     w -= alpha * fgradient(w, X_, y)                      # gradient step
#      28     new_loss = empirical_risk(X_, y, logistic_loss, w) # compute loss
#      30     history.append(new_loss)
#
# TypeError: fgradient() takes 2 positional arguments but 3 were given

# %%
alpha = 0.05
w_0 = 0.5
w_1 = 0.5
w = np.array([1,1])
print(w)
gradient = np.array(fgradient(w_0,w_1))

for i in range(10):
    w = w - alpha * gradient
# Out:
# [1 1]

# %%
print(w)
# Out:
# [0.75777189 0.75777189]
